# %%
[10,20,30,40] #scaler
array ([10,20,30,40]) #vector machine learning
tensor([10,20,30,40]) #tensor (google) deep learning

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.2.6'

# %%
l1 = [10,20,30,40]
arr1 = np.array(l1)
arr1
# Out:
# array([10, 20, 30, 40])

# %%
l2 = [1,2,3,4]
arr2 = np.array(l2)
arr2
# Out:
# array([1, 2, 3, 4])

# %%
l1*l2
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l1*l2
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
arr1*arr2
# Out:
# array([ 10,  40,  90, 160])

# %%
ans = []
for i,j in zip(l1,l2):
    ans.append(i*j)
ans
# Out:
# [10, 40, 90, 160]

# %%
arr1-arr2
# Out:
# array([ 9, 18, 27, 36])

# %%
import time 
start = time.time()
l1 = range (1,1000000)
l2 = range (1,1000000)
ans =[i*j for i,j in zip(l1,l2)]
end = time.time()
print(f'The total time taken :{end-start}')
# Out:
# The total time taken :0.15166401863098145

# %%
list (range (1,10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
np.arange(1,10)
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8, 9])
