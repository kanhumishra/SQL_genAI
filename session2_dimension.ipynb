# %%
import numpy as np

# %%
arr1= np.array([1,2,3,4])

# %%
arr1.ndim
# Out:
# 1

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
type (arr1)
# Out:
# numpy.ndarray

# %%
arr1.shape
arr1.size
# Out:
# 4

# %%
l= [[1,2,3,4],[10,20,30,40]]
arr1 = np.array(l)
arr1
# arr1.ndim
# Out:
# 2

# %%
l1 = [1,2,3,4,5]
l2 = [10,20,30,40,50]
l= [l1,l2]
arr1 = np.array(l)
arr1
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [10, 20, 30, 40, 50]])

# %%
l1 = [1,2,3,4,5]
l2 = [10,20,30,40,50]
l3 = ['a','b','c','d','e']
l= [l1,l2,l3]
arr= np.array(l)
arr
# Out:
# array([['1', '2', '3', '4', '5'],
#        ['10', '20', '30', '40', '50'],
#        ['a', 'b', 'c', 'd', 'e']], dtype='<U21')

# %%
k = [10,20] #2 dimension
np.array(k).shape
# Out:
# (2,)

# %%
a = eval(input ())
# Out:
#  [1,23,4,45,]

# %%
a
# Out:
# [1, 23, 4, 45]

# %%
a.append(12)

# %%
a
# Out:
# [1, 23, 4, 45, 12]

# %%
import ast

# %%
b= ast.literal_eval(input())
